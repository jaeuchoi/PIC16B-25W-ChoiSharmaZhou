
#    creating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a04/a04-050/
#    creating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/b04/b04-116/
#    creating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/b04/b04-128/
#    creating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/b04/b04-034/
#    creating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/b04/b04-096/
#    creating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/b04/b04-004/
#    creating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/b04/b04-107/
#    creating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/b04/b04-081/
#    creating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/b04/b04-054/
# ...
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-08-06.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-06-07.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-09-03.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-07-00.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-10-04.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-10-03.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-08-04.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-08-08.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-05-07.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-03-06.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-08-03.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-05-05.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-05-06.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-04-06.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-10-05.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-05-04.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-04-02.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-10-06.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-02-02.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-02-09.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-06-05.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-02-03.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-09-01.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-02-00.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-06-00.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-03-04.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-06-03.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-04-03.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-02-05.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-10-02.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-09-00.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-04-05.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-03-03.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-01-05.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-02-01.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-04-01.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-03-00.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-07-02.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-05-00.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-03-05.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-09-06.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-04-00.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-01-06.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-01-07.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-06-03.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-08-05.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-01-01.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-08-07.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-09-04.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-00-01.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-01-02.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-01-08.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-00-07.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-10-01.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-08-01.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-04-01.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-00-06.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-07-04.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-05-00.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-03-08.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-02-07.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-06-01.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-03-07.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-09-05.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-08-03.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-01-00.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-06-05.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-03-01.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-08-02.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-06-01.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-00-04.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-04-02.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-00-00.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-04-07.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-05-02.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-00-02.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-06-00.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-04-04.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-05-03.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-04-04.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-04-06.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-06-06.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-07-00.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-02-07.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-04-03.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-07-01.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-08-00.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-07-05.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-05-01.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-02-09.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-00-03.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-06-04.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-07-03.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-05-05.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-02-04.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-03-00.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-01-03.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030x/a01-030x-00-05.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-02-01.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-02-05.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-03-04.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-05-04.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-03-07.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-01-00.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-01-06.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-01-01.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-01-04.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-02-08.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-01-03.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-00-07.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-03-01.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-03-03.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-02-02.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-04-00.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-00-08.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-03-02.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-00-01.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-05-06.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-06-02.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-04-05.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-03-06.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-02-00.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-00-05.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-03-05.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-00-06.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-00-02.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-02-06.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-00-04.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-02-03.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-00-03.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-01-05.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-00-00.png
#   inflating: /content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/a01/a01-030u/a01-030u-01-02.png

# %%
# !pip install --upgrade pip
# !pip install --upgrade jax jaxlib flax optax
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.0.1-py3-none-any.whl.metadata (3.7 kB)
# Downloading pip-25.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 70.9 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-25.0.1
# Requirement already satisfied: jax in /usr/local/lib/python3.11/dist-packages (0.5.2)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.11/dist-packages (0.5.1)
# Requirement already satisfied: flax in /usr/local/lib/python3.11/dist-packages (0.10.4)
# Requirement already satisfied: optax in /usr/local/lib/python3.11/dist-packages (0.2.4)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax) (0.4.1)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.11/dist-packages (from jax) (1.26.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax) (1.14.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from flax) (1.1.0)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.11/dist-packages (from flax) (0.11.8)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.11/dist-packages (from flax) (0.1.72)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.11/dist-packages (from flax) (13.9.4)
# Requirement already satisfied: typing_extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from flax) (4.12.2)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.11/dist-packages (from flax) (6.0.2)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from flax) (0.1.9)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from optax) (1.4.0)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.11/dist-packages (from optax) (0.1.89)
# Requirement already satisfied: etils[epy] in /usr/local/lib/python3.11/dist-packages (from optax) (1.12.1)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex>=0.1.87->optax) (0.12.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax) (2.18.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax) (1.6.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax) (4.25.6)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax) (4.11.0)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax) (3.20.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax) (0.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epy]->optax) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epy]->optax) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epy]->optax) (3.21.0)

# %%
# !pip install --upgrade pip
# !pip install --upgrade "jax[cuda]" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (25.0.1)
# Looking in links: https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Requirement already satisfied: jax[cuda] in /usr/local/lib/python3.11/dist-packages (0.5.2)
# Requirement already satisfied: jaxlib<=0.5.2,>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from jax[cuda]) (0.5.1)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax[cuda]) (0.4.1)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.11/dist-packages (from jax[cuda]) (1.26.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax[cuda]) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax[cuda]) (1.14.1)
# Requirement already satisfied: jax-cuda12-plugin<=0.5.2,>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.2,>=0.5.1; extra == "cuda"->jax[cuda]) (0.5.1)
# Requirement already satisfied: jax-cuda12-pjrt==0.5.1 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin<=0.5.2,>=0.5.1->jax-cuda12-plugin[with_cuda]<=0.5.2,>=0.5.1; extra == "cuda"->jax[cuda]) (0.5.1)
# Requirement already satisfied: nvidia-cublas-cu12>=12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.2,>=0.5.1; extra == "cuda"->jax[cuda]) (12.5.3.2)
# Requirement already satisfied: nvidia-cuda-cupti-cu12>=12.1.105 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.2,>=0.5.1; extra == "cuda"->jax[cuda]) (12.5.82)
# Collecting nvidia-cuda-nvcc-cu12>=12.6.85 (from jax-cuda12-plugin[with_cuda]<=0.5.2,>=0.5.1; extra == "cuda"->jax[cuda])
#   Downloading nvidia_cuda_nvcc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: nvidia-cuda-runtime-cu12>=12.1.105 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.2,>=0.5.1; extra == "cuda"->jax[cuda]) (12.5.82)
# Requirement already satisfied: nvidia-cudnn-cu12<10.0,>=9.1 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.2,>=0.5.1; extra == "cuda"->jax[cuda]) (9.3.0.75)
# Requirement already satisfied: nvidia-cufft-cu12>=11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.2,>=0.5.1; extra == "cuda"->jax[cuda]) (11.2.3.61)
# Requirement already satisfied: nvidia-cusolver-cu12>=11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.2,>=0.5.1; extra == "cuda"->jax[cuda]) (11.6.3.83)
# Requirement already satisfied: nvidia-cusparse-cu12>=12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.2,>=0.5.1; extra == "cuda"->jax[cuda]) (12.5.1.3)
# Requirement already satisfied: nvidia-nccl-cu12>=2.18.1 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.2,>=0.5.1; extra == "cuda"->jax[cuda]) (2.21.5)
# Requirement already satisfied: nvidia-nvjitlink-cu12>=12.1.105 in /usr/local/lib/python3.11/dist-packages (from jax-cuda12-plugin[with_cuda]<=0.5.2,>=0.5.1; extra == "cuda"->jax[cuda]) (12.5.82)
# Downloading nvidia_cuda_nvcc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (40.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 MB 121.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-cuda-nvcc-cu12
#   Attempting uninstall: nvidia-cuda-nvcc-cu12
#     Found existing installation: nvidia-cuda-nvcc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvcc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvcc-cu12-12.5.82
# Successfully installed nvidia-cuda-nvcc-cu12-12.8.93

# %%
import os
import jax
import jax.numpy as jnp
import numpy as np
import optax
import string
import random
import editdistance
from flax import linen as nn
from PIL import Image, UnidentifiedImageError

# ======= Character Set for IAM Dataset =======
CHARS = string.ascii_lowercase + string.digits + ".,;:'\"!?()&- "  # Ensure space is included at the end
char_to_index = {char: i + 1 for i, char in enumerate(CHARS)}  # Start from 1 (0 is blank)
index_to_char = {i: char for char, i in char_to_index.items()}


class IAMDataset:
    def __init__(self, img_root, label_file, img_size=(32, 128)):
        self.img_root = img_root
        self.img_size = img_size
        self.valid_samples = []

        with open(label_file, "r", encoding="utf-8") as f:
            for line in f:
                if line.startswith("#"):
                    continue
                parts = line.strip().split(" ")
                img_name = parts[0]
                text = " ".join(parts[8:]).lower()
                label = [char_to_index[c] for c in text if c in char_to_index]
                folder1, folder2 = img_name.split("-")[:2]
                img_path = os.path.normpath(os.path.join(self.img_root, folder1, f"{folder1}-{folder2}", img_name + ".png"))

                if os.path.exists(img_path) and self._is_valid_image(img_path):
                    self.valid_samples.append((img_path, label))

    def __len__(self):
        return len(self.valid_samples)

    def __getitem__(self, idx):
        img_path, label = self.valid_samples[idx]
        try:
            image = Image.open(img_path).convert("L")
            image = image.resize((128, 32), Image.BILINEAR)
            image = np.array(image, dtype=np.float32) / 255.0
            image = np.expand_dims(image, axis=-1)

            return image, jnp.array(label, dtype=jnp.int32)
        except (UnidentifiedImageError, OSError):
            return None

    def _is_valid_image(self, img_path):
        try:
            with Image.open(img_path) as img:
                img.verify()
            return True
        except (UnidentifiedImageError, OSError):
            return False

def jax_dataloader(dataset, batch_size=32, shuffle=True):
    indices = list(range(len(dataset)))
    if shuffle:
        random.shuffle(indices)

    for start in range(0, len(indices), batch_size):
        batch_indices = indices[start:start + batch_size]
        batch_samples = [dataset[i] for i in batch_indices if dataset[i] is not None]

        if len(batch_samples) == 0:
            continue

        images, labels = zip(*batch_samples)
        images = jnp.stack(images)

        max_label_length = max(len(label) for label in labels)
        padded_labels = jnp.array([
            jnp.pad(label, (0, max_label_length - len(label)), constant_values=0)  # Ensure blank token at the end
            for label in labels
        ])

        yield images, padded_labels, jnp.array([len(label) for label in labels])


# ======= CRNN Model =======
class CRNN(nn.Module):
    img_height: int
    num_classes: int
    lstm_hidden_size: int = 512  # Fix 2: Increased LSTM size
    num_lstm_layers: int = 2  # Fix 2: Added second LSTM layer

    def setup(self):
      self.conv1 = nn.Conv(features=64, kernel_size=(3, 3), strides=1, padding='SAME')
      self.conv2 = nn.Conv(features=128, kernel_size=(3, 3), strides=1, padding='SAME')
      self.conv3 = nn.Conv(features=256, kernel_size=(3, 3), strides=1, padding='SAME')  # Added third conv layer
      self.conv4 = nn.Conv(features=256, kernel_size=(3, 3), strides=1, padding='SAME')  # Second 256 layer
      self.conv5 = nn.Conv(features=512, kernel_size=(3, 3), strides=1, padding='SAME')  # Final deeper layer
      self.fc = nn.Dense(features=self.num_classes)

      # Bidirectional LSTMs (for Modification 3)
      self.lstm_fw = [nn.LSTMCell(features=self.lstm_hidden_size) for _ in range(self.num_lstm_layers)]
      self.lstm_bw = [nn.LSTMCell(features=self.lstm_hidden_size) for _ in range(self.num_lstm_layers)]

    @nn.compact
    def __call__(self, x, train=True):  # Add train argument
      x = nn.relu(self.conv1(x))
      x = nn.BatchNorm(use_running_average=not train)(x)  # Pass use_running_average
      x = nn.Dropout(0.3, deterministic=not train)(x)  # Dropout must also use deterministic
      x = nn.max_pool(x, window_shape=(2, 2), strides=(2, 2), padding='SAME')

      x = nn.relu(self.conv2(x))
      x = nn.BatchNorm(use_running_average=not train)(x)
      x = nn.Dropout(0.3, deterministic=not train)(x)
      x = nn.max_pool(x, window_shape=(2, 2), strides=(2, 2), padding='SAME')

      x = nn.relu(self.conv3(x))
      x = nn.BatchNorm(use_running_average=not train)(x)
      x = nn.Dropout(0.3, deterministic=not train)(x)
      x = nn.max_pool(x, window_shape=(2, 2), strides=(2, 2), padding='SAME')

      x = nn.relu(self.conv4(x))
      x = nn.BatchNorm(use_running_average=not train)(x)
      x = nn.Dropout(0.3, deterministic=not train)(x)

      x = nn.relu(self.conv5(x))
      x = nn.BatchNorm(use_running_average=not train)(x)
      x = nn.Dropout(0.3, deterministic=not train)(x)

      b, h, w, c = x.shape
      x = x.reshape(b, w, h * c)

      # Bidirectional LSTMs
      carries_fw = [lstm.initialize_carry(jax.random.PRNGKey(0), (b, self.lstm_hidden_size)) for lstm in self.lstm_fw]
      carries_bw = [lstm.initialize_carry(jax.random.PRNGKey(0), (b, self.lstm_hidden_size)) for lstm in self.lstm_bw]

      outputs = []
      for t in range(x.shape[1]):
          for i, lstm in enumerate(self.lstm_fw):
              carries_fw[i], x_t_fw = lstm(carries_fw[i], x[:, t, :])
          for i, lstm in enumerate(self.lstm_bw):
              carries_bw[i], x_t_bw = lstm(carries_bw[i], x[:, x.shape[1] - t - 1, :])  # Reverse order for BW LSTM
          outputs.append(jnp.concatenate([x_t_fw, x_t_bw], axis=-1))  # Concatenating both directions

      lstm_out = jnp.stack(outputs, axis=1)
      output = self.fc(lstm_out)
      return jax.nn.log_softmax(output, axis=-1)



# ======= Compute Loss Function =======
def loss_fn_with_batch_stats(params, images, labels):
    logits, new_model_state = model.apply(
        {'params': params, 'batch_stats': batch_stats},
        images,
        train=True,
        mutable=['batch_stats'],
        rngs={'dropout': rng}  # Ensure dropout gets a PRNG key
    )
    logit_paddings = jnp.zeros((logits.shape[0], logits.shape[1]), dtype=jnp.int32)
    label_paddings = (labels == 0).astype(jnp.int32)
    loss = optax.ctc_loss(logits, logit_paddings, labels, label_paddings).mean()
    return loss, new_model_state['batch_stats']


# ======= Training Function =======
@jax.jit
def train_step(params, batch_stats, opt_state, images, labels):
    def loss_fn_with_batch_stats(params, images, labels):
        logits, new_model_state = model.apply(
            {'params': params, 'batch_stats': batch_stats},
            images, train=True, mutable=['batch_stats'],
            rngs={'dropout': rng}  # Pass Dropout PRNG
        )
        logit_paddings = jnp.zeros((logits.shape[0], logits.shape[1]), dtype=jnp.int32)
        label_paddings = (labels == 0).astype(jnp.int32)
        loss = optax.ctc_loss(logits, logit_paddings, labels, label_paddings).mean()
        return loss, new_model_state['batch_stats']  # Return updated batch_stats

    (loss, new_batch_stats), grads = jax.value_and_grad(loss_fn_with_batch_stats, has_aux=True)(params, images, labels)
    grads = jax.tree_util.tree_map(lambda g: jnp.clip(g, -1.0, 1.0) if g is not None else 0, grads)

    updates, opt_state = optimizer.update(grads, opt_state)
    params = optax.apply_updates(params, updates)

    return params, new_batch_stats, opt_state, loss


def compute_cer(preds, targets):
    total_chars, total_errors = 0, 0

    for pred, target in zip(preds, targets):
        pred_text = ''.join([index_to_char[i] for i in pred if i in index_to_char])
        target_text = ''.join([index_to_char[i] for i in target if i in index_to_char])

        total_chars += len(target_text)
        total_errors += editdistance.eval(pred_text, target_text)  # Using editdistance

    return total_errors / total_chars if total_chars > 0 else float("inf")

def greedy_decode(preds):
    decoded = []
    prev_char = None
    for i in preds:
        if i == 0:  # Skip blank characters (CTC blank)
            prev_char = None
            continue
        if i != prev_char:  # Avoid repeated characters (CTC rule)
            decoded.append(index_to_char.get(i, "?"))
        prev_char = i
    return "".join(decoded).strip()  # Remove leading/trailing spaces


def evaluate_model(dataset):
    total_loss, batch_count = 0, 0
    all_preds, all_targets = [], []

    for images, labels, label_lengths in jax_dataloader(dataset, batch_size=32, shuffle=False):
        loss, _ = loss_fn_with_batch_stats(params, images, labels)  # Correct loss function call
        total_loss += float(loss)  # Convert to float for accumulation
        batch_count += 1

        logits = model.apply({'params': params, 'batch_stats': batch_stats}, images, train=False, mutable=False)
        preds = jnp.argmax(logits, axis=-1).tolist()

        all_preds.extend(preds)
        all_targets.extend(labels.tolist())

    # Print a few decoded results
    for i in range(min(10, len(all_preds))):  # Avoid index errors if dataset is small
        pred_text = greedy_decode(all_preds[i])  # Use improved CTC decoding
        target_text = "".join([index_to_char.get(c, "?") for c in all_targets[i] if c > 0])  # Ignore padding

        print(f"Decoded Target: {target_text}")
        print(f"Decoded Prediction: {pred_text}")
        print("=" * 40)

    # Compute CER
    cer = compute_cer(all_preds, all_targets)
    avg_loss = total_loss / batch_count if batch_count > 0 else float("inf")

    return avg_loss, cer

# ----------------- In Progress ------------------
# Want to make it get input/print output

def predict_single_image(model, params, batch_stats, image_path):
    # Load and preprocess the image
    try:
        image = Image.open(image_path).convert("L")  # Convert to grayscale
        image = image.resize((128, 32), Image.BILINEAR)  # Resize to match model input
        image = np.array(image, dtype=np.float32) / 255.0  # Normalize pixel values
        image = np.expand_dims(image, axis=-1)  # Add channel dimension
        image = np.expand_dims(image, axis=0)  # Add batch dimension (1, 32, 128, 1)
        
        image_jax = jnp.array(image)  # Convert to JAX array
        
        # Run inference through the model
        logits = model.apply({'params': params, 'batch_stats': batch_stats}, image_jax, train=False, mutable=False)
        preds = jnp.argmax(logits, axis=-1).squeeze().tolist()  # Get predicted indices

        # Decode the prediction
        predicted_text = greedy_decode(preds)

        print(f"Predicted Text: {predicted_text}")
        return predicted_text
    except (UnidentifiedImageError, OSError):
        print("Error loading image.")
        return None



# ======= Training Configuration =======
img_dir = "/content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/"
label_file = "/content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words.txt"

dataset = IAMDataset(img_dir, label_file)
split_idx = int(0.8 * len(dataset))

train_dataset = IAMDataset(img_dir, label_file)
val_dataset = IAMDataset(img_dir, label_file)
train_dataset.valid_samples = dataset.valid_samples[:split_idx]
val_dataset.valid_samples = dataset.valid_samples[split_idx:]

num_classes = len(CHARS) + 1
model = CRNN(img_height=32, num_classes=num_classes, lstm_hidden_size=512)
rng = jax.random.PRNGKey(0)
dummy_input = jnp.ones((1, 32, 128, 1))
print("Dummy input shape:", dummy_input.shape)

variables = model.init({'params': rng, 'dropout': jax.random.PRNGKey(1)}, dummy_input, train=True)
params = variables['params']  # Extract model parameters
batch_stats = variables['batch_stats']  # Extract BatchNorm statistics

schedule = optax.exponential_decay(
    init_value=1e-3,  # Lowered learning rate
    transition_steps=500,
    decay_rate=0.95
)

optimizer = optax.adam(schedule)
opt_state = optimizer.init(params)  # Now params is defined


# ======= Train Model Function =======
def train_model(train_dataset, val_dataset, epochs=10):
    global params, batch_stats, opt_state
    for epoch in range(epochs):
        epoch_loss, batch_count = 0, 0

        for images, labels, label_lengths in jax_dataloader(train_dataset, batch_size=32):
            params, batch_stats, opt_state, loss = train_step(params, batch_stats, opt_state, images, labels)
            epoch_loss += float(loss)
            batch_count += 1

        avg_train_loss = epoch_loss / batch_count if batch_count > 0 else float("inf")
        val_loss, cer = evaluate_model(val_dataset)

        print(f"Epoch [{epoch + 1}/{epochs}], Loss: {avg_train_loss:.4f}, Val Loss: {val_loss:.4f}, CER: {cer:.4f}")


# ======= Train Model =======
train_model(train_dataset, val_dataset, epochs=40)
# Out:
# Dummy input shape: (1, 32, 128, 1)
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: .,
# ========================================
# Decoded Target: background
# Decoded Prediction: .
# ========================================
# Decoded Target: is
# Decoded Prediction: .,.
# ========================================
# Decoded Target: a
# Decoded Prediction: .
# ========================================
# Decoded Target: doctor
# Decoded Prediction: .,
# ========================================
# Decoded Target: of
# Decoded Prediction: .,.
# ========================================
# Decoded Target: 68
# Decoded Prediction: .,.,
# ========================================
# Decoded Target: ,
# Decoded Prediction: .
# ========================================
# Decoded Target: who
# Decoded Prediction: .
# ========================================
# Decoded Target: has
# Decoded Prediction: .
# ========================================
# Decoded Target: practised
# Decoded Prediction: .,.
# ========================================
# Decoded Target: medicine
# Decoded Prediction: .,.
# ========================================
# Decoded Target: for
# Decoded Prediction: .,.
# ========================================
# Decoded Target: 43
# Decoded Prediction: .,
# ========================================
# Decoded Target: years
# Decoded Prediction: .,.
# ========================================
# Decoded Target: ,
# Decoded Prediction: ..
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: .,.
# ========================================
# Decoded Target: as
# Decoded Prediction: ...
# ========================================
# Decoded Target: a
# Decoded Prediction: .
# ========================================
# Epoch [1/50], Loss: 72.3488, Val Loss: 12.3025, CER: 3.4824
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction:
# ========================================
# Decoded Target: background
# Decoded Prediction:
# ========================================
# Decoded Target: is
# Decoded Prediction:
# ========================================
# Decoded Target: a
# Decoded Prediction:
# ========================================
# Decoded Target: doctor
# Decoded Prediction:
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: .
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Decoded Target: has
# Decoded Prediction:
# ========================================
# Decoded Target: practised
# Decoded Prediction:
# ========================================
# Decoded Target: medicine
# Decoded Prediction:
# ========================================
# Decoded Target: for
# Decoded Prediction:
# ========================================
# Decoded Target: 43
# Decoded Prediction:
# ========================================
# Decoded Target: years
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: chiefly
# Decoded Prediction:
# ========================================
# Decoded Target: as
# Decoded Prediction:
# ========================================
# Decoded Target: a
# Decoded Prediction:
# ========================================
# Epoch [2/50], Loss: 69.7794, Val Loss: 10.9260, CER: 0.9989
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: .
# ========================================
# Decoded Target: background
# Decoded Prediction:
# ========================================
# Decoded Target: is
# Decoded Prediction:
# ========================================
# Decoded Target: a
# Decoded Prediction:
# ========================================
# Decoded Target: doctor
# Decoded Prediction:
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: .
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Decoded Target: has
# Decoded Prediction: .
# ========================================
# Decoded Target: practised
# Decoded Prediction: o
# ========================================
# Decoded Target: medicine
# Decoded Prediction:
# ========================================
# Decoded Target: for
# Decoded Prediction:
# ========================================
# Decoded Target: 43
# Decoded Prediction: .
# ========================================
# Decoded Target: years
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: chiefly
# Decoded Prediction:
# ========================================
# Decoded Target: as
# Decoded Prediction: .
# ========================================
# Decoded Target: a
# Decoded Prediction:
# ========================================
# Epoch [3/50], Loss: 68.3172, Val Loss: 10.3154, CER: 0.9944
# Decoded Target: "
# Decoded Prediction:
# ========================================
# Decoded Target: my
# Decoded Prediction:
# ========================================
# Decoded Target: background
# Decoded Prediction: oo
# ========================================
# Decoded Target: is
# Decoded Prediction:
# ========================================
# Decoded Target: a
# Decoded Prediction:
# ========================================
# Decoded Target: doctor
# Decoded Prediction:
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Decoded Target: has
# Decoded Prediction:
# ========================================
# Decoded Target: practised
# Decoded Prediction: o
# ========================================
# Decoded Target: medicine
# Decoded Prediction: a
# ========================================
# Decoded Target: for
# Decoded Prediction:
# ========================================
# Decoded Target: 43
# Decoded Prediction:
# ========================================
# Decoded Target: years
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction: .
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: o
# ========================================
# Decoded Target: as
# Decoded Prediction:
# ========================================
# Decoded Target: a
# Decoded Prediction:
# ========================================
# Epoch [4/50], Loss: 67.0523, Val Loss: 9.4811, CER: 0.9804
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: .
# ========================================
# Decoded Target: background
# Decoded Prediction: neommn
# ========================================
# Decoded Target: is
# Decoded Prediction: :
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction:
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Decoded Target: has
# Decoded Prediction:
# ========================================
# Decoded Target: practised
# Decoded Prediction: aod
# ========================================
# Decoded Target: medicine
# Decoded Prediction: an
# ========================================
# Decoded Target: for
# Decoded Prediction: n
# ========================================
# Decoded Target: 43
# Decoded Prediction:
# ========================================
# Decoded Target: years
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction: .
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: on
# ========================================
# Decoded Target: as
# Decoded Prediction: .
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [5/50], Loss: 65.8953, Val Loss: 9.0779, CER: 0.8982
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: .
# ========================================
# Decoded Target: background
# Decoded Prediction: nvormen
# ========================================
# Decoded Target: is
# Decoded Prediction: i
# ========================================
# Decoded Target: a
# Decoded Prediction:
# ========================================
# Decoded Target: doctor
# Decoded Prediction: h
# ========================================
# Decoded Target: of
# Decoded Prediction: .
# ========================================
# Decoded Target: 68
# Decoded Prediction: .
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Decoded Target: has
# Decoded Prediction:
# ========================================
# Decoded Target: practised
# Decoded Prediction: ud
# ========================================
# Decoded Target: medicine
# Decoded Prediction: ann
# ========================================
# Decoded Target: for
# Decoded Prediction: i
# ========================================
# Decoded Target: 43
# Decoded Prediction: .
# ========================================
# Decoded Target: years
# Decoded Prediction: .
# ========================================
# Decoded Target: ,
# Decoded Prediction: .
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: oin
# ========================================
# Decoded Target: as
# Decoded Prediction: .
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [6/50], Loss: 64.6533, Val Loss: 8.8424, CER: 0.8545
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: t
# ========================================
# Decoded Target: background
# Decoded Prediction: poemnd
# ========================================
# Decoded Target: is
# Decoded Prediction: i
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: an
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: an
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Decoded Target: has
# Decoded Prediction: na
# ========================================
# Decoded Target: practised
# Decoded Prediction: auod
# ========================================
# Decoded Target: medicine
# Decoded Prediction: an
# ========================================
# Decoded Target: for
# Decoded Prediction: n
# ========================================
# Decoded Target: 43
# Decoded Prediction: n
# ========================================
# Decoded Target: years
# Decoded Prediction: aon
# ========================================
# Decoded Target: ,
# Decoded Prediction: .
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: oin
# ========================================
# Decoded Target: as
# Decoded Prediction: o
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [7/50], Loss: 63.6322, Val Loss: 8.2935, CER: 0.7566
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: t
# ========================================
# Decoded Target: background
# Decoded Prediction: nomenmen
# ========================================
# Decoded Target: is
# Decoded Prediction: i
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: naon
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: m
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: -
# ========================================
# Decoded Target: has
# Decoded Prediction: a
# ========================================
# Decoded Target: practised
# Decoded Prediction: momoed
# ========================================
# Decoded Target: medicine
# Decoded Prediction: ansn
# ========================================
# Decoded Target: for
# Decoded Prediction: n
# ========================================
# Decoded Target: 43
# Decoded Prediction: a
# ========================================
# Decoded Target: years
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction: ,
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: oiwy
# ========================================
# Decoded Target: as
# Decoded Prediction: o
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [8/50], Loss: 62.6270, Val Loss: 8.2163, CER: 0.7599
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: t
# ========================================
# Decoded Target: background
# Decoded Prediction: nonvoermn
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: nan
# ========================================
# Decoded Target: of
# Decoded Prediction: a
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Decoded Target: has
# Decoded Prediction: a
# ========================================
# Decoded Target: practised
# Decoded Prediction: momoed
# ========================================
# Decoded Target: medicine
# Decoded Prediction: a
# ========================================
# Decoded Target: for
# Decoded Prediction: fn
# ========================================
# Decoded Target: 43
# Decoded Prediction: "s
# ========================================
# Decoded Target: years
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction: .
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: aiy
# ========================================
# Decoded Target: as
# Decoded Prediction: a
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [9/50], Loss: 61.7042, Val Loss: 8.1496, CER: 0.7473
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: t
# ========================================
# Decoded Target: background
# Decoded Prediction: povernment
# ========================================
# Decoded Target: is
# Decoded Prediction: i
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: tatan
# ========================================
# Decoded Target: of
# Decoded Prediction: .
# ========================================
# Decoded Target: 68
# Decoded Prediction: m
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: -
# ========================================
# Decoded Target: has
# Decoded Prediction: mas
# ========================================
# Decoded Target: practised
# Decoded Prediction: uomoted
# ========================================
# Decoded Target: medicine
# Decoded Prediction: aumue
# ========================================
# Decoded Target: for
# Decoded Prediction: f
# ========================================
# Decoded Target: 43
# Decoded Prediction: n
# ========================================
# Decoded Target: years
# Decoded Prediction: no
# ========================================
# Decoded Target: ,
# Decoded Prediction: .
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: ciy
# ========================================
# Decoded Target: as
# Decoded Prediction: a
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [10/50], Loss: 60.7901, Val Loss: 8.2410, CER: 0.6861
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: t
# ========================================
# Decoded Target: background
# Decoded Prediction: govmernnment
# ========================================
# Decoded Target: is
# Decoded Prediction: i
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: hatn
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: -
# ========================================
# Decoded Target: has
# Decoded Prediction: ma
# ========================================
# Decoded Target: practised
# Decoded Prediction: uomoted
# ========================================
# Decoded Target: medicine
# Decoded Prediction: aul
# ========================================
# Decoded Target: for
# Decoded Prediction: f
# ========================================
# Decoded Target: 43
# Decoded Prediction: "
# ========================================
# Decoded Target: years
# Decoded Prediction: u
# ========================================
# Decoded Target: ,
# Decoded Prediction: .
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: aig
# ========================================
# Decoded Target: as
# Decoded Prediction: o
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [11/50], Loss: 60.0066, Val Loss: 8.1885, CER: 0.7244
# Decoded Target: "
# Decoded Prediction:
# ========================================
# Decoded Target: my
# Decoded Prediction: ny
# ========================================
# Decoded Target: background
# Decoded Prediction: gonvmennment
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: ataon
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: -
# ========================================
# Decoded Target: has
# Decoded Prediction: was
# ========================================
# Decoded Target: practised
# Decoded Prediction: momited
# ========================================
# Decoded Target: medicine
# Decoded Prediction: uniu
# ========================================
# Decoded Target: for
# Decoded Prediction: fo
# ========================================
# Decoded Target: 43
# Decoded Prediction: ns
# ========================================
# Decoded Target: years
# Decoded Prediction: nsa
# ========================================
# Decoded Target: ,
# Decoded Prediction: .
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: ciwng
# ========================================
# Decoded Target: as
# Decoded Prediction: as
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [12/50], Loss: 59.4142, Val Loss: 8.2229, CER: 0.6461
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: ty
# ========================================
# Decoded Target: background
# Decoded Prediction: novenpment
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: totn
# ========================================
# Decoded Target: of
# Decoded Prediction: ,
# ========================================
# Decoded Target: 68
# Decoded Prediction: an
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: -
# ========================================
# Decoded Target: has
# Decoded Prediction: nas
# ========================================
# Decoded Target: practised
# Decoded Prediction: mooited
# ========================================
# Decoded Target: medicine
# Decoded Prediction: inliae
# ========================================
# Decoded Target: for
# Decoded Prediction: for
# ========================================
# Decoded Target: 43
# Decoded Prediction: nis
# ========================================
# Decoded Target: years
# Decoded Prediction: no
# ========================================
# Decoded Target: ,
# Decoded Prediction: ,
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: aits
# ========================================
# Decoded Target: as
# Decoded Prediction: a
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [13/50], Loss: 58.9150, Val Loss: 8.5285, CER: 0.6399
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: l
# ========================================
# Decoded Target: background
# Decoded Prediction: novernment
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: atuon
# ========================================
# Decoded Target: of
# Decoded Prediction: a
# ========================================
# Decoded Target: 68
# Decoded Prediction: m
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: -
# ========================================
# Decoded Target: has
# Decoded Prediction: mas
# ========================================
# Decoded Target: practised
# Decoded Prediction: momoiued
# ========================================
# Decoded Target: medicine
# Decoded Prediction: anruce
# ========================================
# Decoded Target: for
# Decoded Prediction: fm
# ========================================
# Decoded Target: 43
# Decoded Prediction: n
# ========================================
# Decoded Target: years
# Decoded Prediction: n
# ========================================
# Decoded Target: ,
# Decoded Prediction: .
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: ciwig
# ========================================
# Decoded Target: as
# Decoded Prediction: o
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [14/50], Loss: 58.5393, Val Loss: 8.3207, CER: 0.6710
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: ny
# ========================================
# Decoded Target: background
# Decoded Prediction: novmernnment
# ========================================
# Decoded Target: is
# Decoded Prediction: in
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: ttor
# ========================================
# Decoded Target: of
# Decoded Prediction: a
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction: "
# ========================================
# Decoded Target: who
# Decoded Prediction: -o
# ========================================
# Decoded Target: has
# Decoded Prediction: mas
# ========================================
# Decoded Target: practised
# Decoded Prediction: mumoited
# ========================================
# Decoded Target: medicine
# Decoded Prediction: indsase
# ========================================
# Decoded Target: for
# Decoded Prediction: frr
# ========================================
# Decoded Target: 43
# Decoded Prediction: "s
# ========================================
# Decoded Target: years
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction: .
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: ciy
# ========================================
# Decoded Target: as
# Decoded Prediction: an
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [15/50], Loss: 58.2894, Val Loss: 8.5434, CER: 0.6631
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: ny
# ========================================
# Decoded Target: background
# Decoded Prediction: novmernnmnt
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: latr
# ========================================
# Decoded Target: of
# Decoded Prediction: "
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction: "
# ========================================
# Decoded Target: who
# Decoded Prediction: -o
# ========================================
# Decoded Target: has
# Decoded Prediction: was
# ========================================
# Decoded Target: practised
# Decoded Prediction: momouhed
# ========================================
# Decoded Target: medicine
# Decoded Prediction: unlue
# ========================================
# Decoded Target: for
# Decoded Prediction: fo
# ========================================
# Decoded Target: 43
# Decoded Prediction: ns
# ========================================
# Decoded Target: years
# Decoded Prediction: nes
# ========================================
# Decoded Target: ,
# Decoded Prediction: ,
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: ciey
# ========================================
# Decoded Target: as
# Decoded Prediction: an
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [16/50], Loss: 58.2219, Val Loss: 8.6499, CER: 0.6226
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: ny
# ========================================
# Decoded Target: background
# Decoded Prediction: govmernment
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: ator
# ========================================
# Decoded Target: of
# Decoded Prediction: a
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Decoded Target: has
# Decoded Prediction: mas
# ========================================
# Decoded Target: practised
# Decoded Prediction: momited
# ========================================
# Decoded Target: medicine
# Decoded Prediction: ansiuece
# ========================================
# Decoded Target: for
# Decoded Prediction: f
# ========================================
# Decoded Target: 43
# Decoded Prediction: ns
# ========================================
# Decoded Target: years
# Decoded Prediction: ne
# ========================================
# Decoded Target: ,
# Decoded Prediction: ,
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: ciwg
# ========================================
# Decoded Target: as
# Decoded Prediction: an
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [17/50], Loss: 57.9855, Val Loss: 8.7190, CER: 0.6242
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: ny
# ========================================
# Decoded Target: background
# Decoded Prediction: governnmnt
# ========================================
# Decoded Target: is
# Decoded Prediction: i
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: datr
# ========================================
# Decoded Target: of
# Decoded Prediction: a
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction: -
# ========================================
# Decoded Target: who
# Decoded Prediction: -o
# ========================================
# Decoded Target: has
# Decoded Prediction: mas
# ========================================
# Decoded Target: practised
# Decoded Prediction: momiited
# ========================================
# Decoded Target: medicine
# Decoded Prediction: aidisase
# ========================================
# Decoded Target: for
# Decoded Prediction: fir
# ========================================
# Decoded Target: 43
# Decoded Prediction: "s
# ========================================
# Decoded Target: years
# Decoded Prediction: ns
# ========================================
# Decoded Target: ,
# Decoded Prediction: .
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: city
# ========================================
# Decoded Target: as
# Decoded Prediction: a
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [18/50], Loss: 57.9493, Val Loss: 8.8530, CER: 0.6461
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: n
# ========================================
# Decoded Target: background
# Decoded Prediction: aonvmennmnt
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: natn
# ========================================
# Decoded Target: of
# Decoded Prediction: .
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: t
# ========================================
# Decoded Target: has
# Decoded Prediction: nas
# ========================================
# Decoded Target: practised
# Decoded Prediction: momited
# ========================================
# Decoded Target: medicine
# Decoded Prediction: unliue
# ========================================
# Decoded Target: for
# Decoded Prediction: fn
# ========================================
# Decoded Target: 43
# Decoded Prediction: "s
# ========================================
# Decoded Target: years
# Decoded Prediction: n
# ========================================
# Decoded Target: ,
# Decoded Prediction: .
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: ciwg
# ========================================
# Decoded Target: as
# Decoded Prediction: a
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [19/50], Loss: 57.8148, Val Loss: 8.9949, CER: 0.6718
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: ty
# ========================================
# Decoded Target: background
# Decoded Prediction: govmennmnt
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: naton
# ========================================
# Decoded Target: of
# Decoded Prediction: .
# ========================================
# Decoded Target: 68
# Decoded Prediction: an
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: -o
# ========================================
# Decoded Target: has
# Decoded Prediction: nas
# ========================================
# Decoded Target: practised
# Decoded Prediction: mumiited
# ========================================
# Decoded Target: medicine
# Decoded Prediction: unliae
# ========================================
# Decoded Target: for
# Decoded Prediction: fir
# ========================================
# Decoded Target: 43
# Decoded Prediction: ns
# ========================================
# Decoded Target: years
# Decoded Prediction: ns
# ========================================
# Decoded Target: ,
# Decoded Prediction: ,
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: ciwy
# ========================================
# Decoded Target: as
# Decoded Prediction: a
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [20/50], Loss: 57.7222, Val Loss: 9.1044, CER: 0.6223
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: a
# ========================================
# Decoded Target: background
# Decoded Prediction: govmernment
# ========================================
# Decoded Target: is
# Decoded Prediction: i:
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: lauor
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: m
# ========================================
# Decoded Target: ,
# Decoded Prediction: ,
# ========================================
# Decoded Target: who
# Decoded Prediction: -
# ========================================
# Decoded Target: has
# Decoded Prediction: nas
# ========================================
# Decoded Target: practised
# Decoded Prediction: momoiued
# ========================================
# Decoded Target: medicine
# Decoded Prediction: anucn
# ========================================
# Decoded Target: for
# Decoded Prediction: f
# ========================================
# Decoded Target: 43
# Decoded Prediction: "
# ========================================
# Decoded Target: years
# Decoded Prediction: no
# ========================================
# Decoded Target: ,
# Decoded Prediction: ,
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: ciwng
# ========================================
# Decoded Target: as
# Decoded Prediction: a
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [21/50], Loss: 57.6557, Val Loss: 9.0461, CER: 0.6746
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: nn
# ========================================
# Decoded Target: background
# Decoded Prediction: gonvmernment
# ========================================
# Decoded Target: is
# Decoded Prediction: in
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: dator
# ========================================
# Decoded Target: of
# Decoded Prediction: at
# ========================================
# Decoded Target: 68
# Decoded Prediction: an
# ========================================
# Decoded Target: ,
# Decoded Prediction: )i
# ========================================
# Decoded Target: who
# Decoded Prediction: -o
# ========================================
# Decoded Target: has
# Decoded Prediction: was
# ========================================
# Decoded Target: practised
# Decoded Prediction: momoited
# ========================================
# Decoded Target: medicine
# Decoded Prediction: undiae
# ========================================
# Decoded Target: for
# Decoded Prediction: for
# ========================================
# Decoded Target: 43
# Decoded Prediction: nis
# ========================================
# Decoded Target: years
# Decoded Prediction: ns
# ========================================
# Decoded Target: ,
# Decoded Prediction: ,
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: cily
# ========================================
# Decoded Target: as
# Decoded Prediction: as
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [22/50], Loss: 57.5992, Val Loss: 9.3412, CER: 0.6245
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: tn
# ========================================
# Decoded Target: background
# Decoded Prediction: gonvmennment
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: lator
# ========================================
# Decoded Target: of
# Decoded Prediction: a
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction: "
# ========================================
# Decoded Target: who
# Decoded Prediction: t
# ========================================
# Decoded Target: has
# Decoded Prediction: was
# ========================================
# Decoded Target: practised
# Decoded Prediction: pocoited
# ========================================
# Decoded Target: medicine
# Decoded Prediction: andue
# ========================================
# Decoded Target: for
# Decoded Prediction: for
# ========================================
# Decoded Target: 43
# Decoded Prediction: "
# ========================================
# Decoded Target: years
# Decoded Prediction: ns
# ========================================
# Decoded Target: ,
# Decoded Prediction: .
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: ciy
# ========================================
# Decoded Target: as
# Decoded Prediction: a
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [23/50], Loss: 57.5488, Val Loss: 9.4749, CER: 0.6024
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: tn
# ========================================
# Decoded Target: background
# Decoded Prediction: govmernment
# ========================================
# Decoded Target: is
# Decoded Prediction: in
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: nar
# ========================================
# Decoded Target: of
# Decoded Prediction: o
# ========================================
# Decoded Target: 68
# Decoded Prediction: m
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: t
# ========================================
# Decoded Target: has
# Decoded Prediction: nas
# ========================================
# Decoded Target: practised
# Decoded Prediction: momoiued
# ========================================
# Decoded Target: medicine
# Decoded Prediction: unduce
# ========================================
# Decoded Target: for
# Decoded Prediction: foo
# ========================================
# Decoded Target: 43
# Decoded Prediction: "s
# ========================================
# Decoded Target: years
# Decoded Prediction: n
# ========================================
# Decoded Target: ,
# Decoded Prediction: ,
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: ciwg
# ========================================
# Decoded Target: as
# Decoded Prediction: a
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [24/50], Loss: 57.5256, Val Loss: 9.7307, CER: 0.6343
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: tn
# ========================================
# Decoded Target: background
# Decoded Prediction: gonvmernment
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: lator
# ========================================
# Decoded Target: of
# Decoded Prediction: o
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: t
# ========================================
# Decoded Target: has
# Decoded Prediction: was
# ========================================
# Decoded Target: practised
# Decoded Prediction: momoited
# ========================================
# Decoded Target: medicine
# Decoded Prediction: anducr
# ========================================
# Decoded Target: for
# Decoded Prediction: foo
# ========================================
# Decoded Target: 43
# Decoded Prediction: "s
# ========================================
# Decoded Target: years
# Decoded Prediction: n
# ========================================
# Decoded Target: ,
# Decoded Prediction: ,
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: ciwy
# ========================================
# Decoded Target: as
# Decoded Prediction: a
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [25/50], Loss: 57.5036, Val Loss: 9.6867, CER: 0.5870
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: t
# ========================================
# Decoded Target: background
# Decoded Prediction: govmenmnt
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: laton
# ========================================
# Decoded Target: of
# Decoded Prediction: o
# ========================================
# Decoded Target: 68
# Decoded Prediction: o
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: -
# ========================================
# Decoded Target: has
# Decoded Prediction: mas
# ========================================
# Decoded Target: practised
# Decoded Prediction: memoited
# ========================================
# Decoded Target: medicine
# Decoded Prediction: undiue
# ========================================
# Decoded Target: for
# Decoded Prediction: for
# ========================================
# Decoded Target: 43
# Decoded Prediction: "
# ========================================
# Decoded Target: years
# Decoded Prediction: n
# ========================================
# Decoded Target: ,
# Decoded Prediction: .
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: ciy
# ========================================
# Decoded Target: as
# Decoded Prediction: a
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [26/50], Loss: 57.4809, Val Loss: 9.8208, CER: 0.6052
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: to
# ========================================
# Decoded Target: background
# Decoded Prediction: govmernmnt
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: dator
# ========================================
# Decoded Target: of
# Decoded Prediction: a
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: t
# ========================================
# Decoded Target: has
# Decoded Prediction: was
# ========================================
# Decoded Target: practised
# Decoded Prediction: pemoited
# ========================================
# Decoded Target: medicine
# Decoded Prediction: andiae
# ========================================
# Decoded Target: for
# Decoded Prediction: for
# ========================================
# Decoded Target: 43
# Decoded Prediction: "s
# ========================================
# Decoded Target: years
# Decoded Prediction: n
# ========================================
# Decoded Target: ,
# Decoded Prediction: .
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: city
# ========================================
# Decoded Target: as
# Decoded Prediction: a
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [27/50], Loss: 57.4793, Val Loss: 9.6140, CER: 0.5884
# Decoded Target: "
# Decoded Prediction: -
# ========================================
# Decoded Target: my
# Decoded Prediction: a
# ========================================
# Decoded Target: background
# Decoded Prediction: bameognmnd
# ========================================
# Decoded Target: is
# Decoded Prediction: i
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: nots
# ========================================
# Decoded Target: of
# Decoded Prediction: ,
# ...
# Decoded Prediction: a
# ========================================
# Epoch [41/50], Loss: 57.5421, Val Loss: 10.5319, CER: 0.6018
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: tn
# ========================================
# Decoded Target: background
# Decoded Prediction: governmnt
# ========================================
# Decoded Target: is
# Decoded Prediction: in
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: ntor
# ========================================
# Decoded Target: of
# Decoded Prediction: at
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction: )
# ========================================
# Decoded Target: who
# Decoded Prediction: to
# ========================================
# Decoded Target: has
# Decoded Prediction: nos
# ========================================
# Decoded Target: practised
# Decoded Prediction: momoited
# ========================================
# Decoded Target: medicine
# Decoded Prediction: unuue
# ========================================
# Decoded Target: for
# Decoded Prediction: fon
# ========================================
# Decoded Target: 43
# Decoded Prediction: ns
# ========================================
# Decoded Target: years
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction: ,
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: ciwny
# ========================================
# Decoded Target: as
# Decoded Prediction: as
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [42/50], Loss: 57.4792, Val Loss: 10.7381, CER: 0.5915
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: tn
# ========================================
# Decoded Target: background
# Decoded Prediction: government
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: totor
# ========================================
# Decoded Target: of
# Decoded Prediction: at
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: t
# ========================================
# Decoded Target: has
# Decoded Prediction: no
# ========================================
# Decoded Target: practised
# Decoded Prediction: mooited
# ========================================
# Decoded Target: medicine
# Decoded Prediction: uvue
# ========================================
# Decoded Target: for
# Decoded Prediction: for
# ========================================
# Decoded Target: 43
# Decoded Prediction: n
# ========================================
# Decoded Target: years
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction: .
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: ciey
# ========================================
# Decoded Target: as
# Decoded Prediction: an
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [43/50], Loss: 57.4680, Val Loss: 10.6510, CER: 0.5935
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: tn
# ========================================
# Decoded Target: background
# Decoded Prediction: govmennmnt
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: tatr
# ========================================
# Decoded Target: of
# Decoded Prediction: at
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: to
# ========================================
# Decoded Target: has
# Decoded Prediction: wos
# ========================================
# Decoded Target: practised
# Decoded Prediction: mooited
# ========================================
# Decoded Target: medicine
# Decoded Prediction: wlae
# ========================================
# Decoded Target: for
# Decoded Prediction: for
# ========================================
# Decoded Target: 43
# Decoded Prediction: ns
# ========================================
# Decoded Target: years
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction: ,
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: ciy
# ========================================
# Decoded Target: as
# Decoded Prediction: as
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [44/50], Loss: 57.4708, Val Loss: 10.5731, CER: 0.6128
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: nn
# ========================================
# Decoded Target: background
# Decoded Prediction: governmnt
# ========================================
# Decoded Target: is
# Decoded Prediction: in
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: dtor
# ========================================
# Decoded Target: of
# Decoded Prediction: a
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: t
# ========================================
# Decoded Target: has
# Decoded Prediction: hos
# ========================================
# Decoded Target: practised
# Decoded Prediction: momoiued
# ========================================
# Decoded Target: medicine
# Decoded Prediction: uduece
# ========================================
# Decoded Target: for
# Decoded Prediction: fon
# ========================================
# Decoded Target: 43
# Decoded Prediction: ns
# ========================================
# Decoded Target: years
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction: ,
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: city
# ========================================
# Decoded Target: as
# Decoded Prediction: as
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [45/50], Loss: 57.4581, Val Loss: 10.7850, CER: 0.5845
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: h.
# ========================================
# Decoded Target: background
# Decoded Prediction: governnmn
# ========================================
# Decoded Target: is
# Decoded Prediction: in
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: dotr
# ========================================
# Decoded Target: of
# Decoded Prediction: a
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: to
# ========================================
# Decoded Target: has
# Decoded Prediction: has
# ========================================
# Decoded Target: practised
# Decoded Prediction: mooiued
# ========================================
# Decoded Target: medicine
# Decoded Prediction: auuu
# ========================================
# Decoded Target: for
# Decoded Prediction: foo
# ========================================
# Decoded Target: 43
# Decoded Prediction: n
# ========================================
# Decoded Target: years
# Decoded Prediction: n
# ========================================
# Decoded Target: ,
# Decoded Prediction: ,
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: cuty
# ========================================
# Decoded Target: as
# Decoded Prediction: an
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [46/50], Loss: 57.4512, Val Loss: 10.6829, CER: 0.6228
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: nn
# ========================================
# Decoded Target: background
# Decoded Prediction: governmn
# ========================================
# Decoded Target: is
# Decoded Prediction: in
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: hatr
# ========================================
# Decoded Target: of
# Decoded Prediction: a
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: -
# ========================================
# Decoded Target: has
# Decoded Prediction: was
# ========================================
# Decoded Target: practised
# Decoded Prediction: momoiued
# ========================================
# Decoded Target: medicine
# Decoded Prediction: ulue
# ========================================
# Decoded Target: for
# Decoded Prediction: for
# ========================================
# Decoded Target: 43
# Decoded Prediction: n
# ========================================
# Decoded Target: years
# Decoded Prediction: r
# ========================================
# Decoded Target: ,
# Decoded Prediction: ,
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: ciy
# ========================================
# Decoded Target: as
# Decoded Prediction: an
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [47/50], Loss: 57.4288, Val Loss: 10.7664, CER: 0.6004
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: nn
# ========================================
# Decoded Target: background
# Decoded Prediction: governmnt
# ========================================
# Decoded Target: is
# Decoded Prediction: in
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: dtor
# ========================================
# Decoded Target: of
# Decoded Prediction: a
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: to
# ========================================
# Decoded Target: has
# Decoded Prediction: was
# ========================================
# Decoded Target: practised
# Decoded Prediction: momoiued
# ========================================
# Decoded Target: medicine
# Decoded Prediction: uduece
# ========================================
# Decoded Target: for
# Decoded Prediction: for
# ========================================
# Decoded Target: 43
# Decoded Prediction: ns
# ========================================
# Decoded Target: years
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction: ,
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: ciity
# ========================================
# Decoded Target: as
# Decoded Prediction: a
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [48/50], Loss: 57.4087, Val Loss: 10.7780, CER: 0.5893
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: nn
# ========================================
# Decoded Target: background
# Decoded Prediction: govennmnt
# ========================================
# Decoded Target: is
# Decoded Prediction: in
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: dtor
# ========================================
# Decoded Target: of
# Decoded Prediction: "t
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: no
# ========================================
# Decoded Target: has
# Decoded Prediction: hos
# ========================================
# Decoded Target: practised
# Decoded Prediction: momoiued
# ========================================
# Decoded Target: medicine
# Decoded Prediction: uduce
# ========================================
# Decoded Target: for
# Decoded Prediction: for
# ========================================
# Decoded Target: 43
# Decoded Prediction: ns
# ========================================
# Decoded Target: years
# Decoded Prediction: n
# ========================================
# Decoded Target: ,
# Decoded Prediction: ,
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: ciy
# ========================================
# Decoded Target: as
# Decoded Prediction: an
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [49/50], Loss: 57.3947, Val Loss: 11.0824, CER: 0.5848
# Decoded Target: "
# Decoded Prediction: .
# ========================================
# Decoded Target: my
# Decoded Prediction: nn
# ========================================
# Decoded Target: background
# Decoded Prediction: governmn
# ========================================
# Decoded Target: is
# Decoded Prediction: in
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: toor
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: t
# ========================================
# Decoded Target: has
# Decoded Prediction: mos
# ========================================
# Decoded Target: practised
# Decoded Prediction: mocoiued
# ========================================
# Decoded Target: medicine
# Decoded Prediction: adure
# ========================================
# Decoded Target: for
# Decoded Prediction: for
# ========================================
# Decoded Target: 43
# Decoded Prediction: ns
# ========================================
# Decoded Target: years
# Decoded Prediction: n
# ========================================
# Decoded Target: ,
# Decoded Prediction: ,
# ========================================
# Decoded Target: chiefly
# Decoded Prediction: cuy
# ========================================
# Decoded Target: as
# Decoded Prediction: a
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Epoch [50/50], Loss: 57.4186, Val Loss: 10.9927, CER: 0.6094

# %%
import os
import jax
import jax.numpy as jnp
import numpy as np
import optax
import string
import random
import editdistance
from flax import linen as nn
from PIL import Image, UnidentifiedImageError

# ======= Character Set for IAM Dataset =======
CHARS = string.ascii_lowercase + string.digits + ".,;:'\"!?()&- "  # Ensure space is included at the end
char_to_index = {char: i + 1 for i, char in enumerate(CHARS)}  # Start from 1 (0 is blank)
index_to_char = {i: char for char, i in char_to_index.items()}


class IAMDataset:
    def __init__(self, img_root, label_file, img_size=(32, 128)):
        self.img_root = img_root
        self.img_size = img_size
        self.valid_samples = []

        with open(label_file, "r", encoding="utf-8") as f:
            for line in f:
                if line.startswith("#"):
                    continue
                parts = line.strip().split(" ")
                img_name = parts[0]
                text = " ".join(parts[8:]).lower()
                label = [char_to_index[c] for c in text if c in char_to_index]
                folder1, folder2 = img_name.split("-")[:2]
                img_path = os.path.normpath(os.path.join(self.img_root, folder1, f"{folder1}-{folder2}", img_name + ".png"))

                if os.path.exists(img_path) and self._is_valid_image(img_path):
                    self.valid_samples.append((img_path, label))

    def __len__(self):
        return len(self.valid_samples)

    def __getitem__(self, idx):
        img_path, label = self.valid_samples[idx]
        try:
            image = Image.open(img_path).convert("L")
            image = image.resize((128, 32), Image.BILINEAR)
            image = np.array(image, dtype=np.float32) / 255.0
            image = np.expand_dims(image, axis=-1)

            return image, jnp.array(label, dtype=jnp.int32)
        except (UnidentifiedImageError, OSError):
            return None

    def _is_valid_image(self, img_path):
        try:
            with Image.open(img_path) as img:
                img.verify()
            return True
        except (UnidentifiedImageError, OSError):
            return False

def jax_dataloader(dataset, batch_size=32, shuffle=True):
    indices = list(range(len(dataset)))
    if shuffle:
        random.shuffle(indices)

    for start in range(0, len(indices), batch_size):
        batch_indices = indices[start:start + batch_size]
        batch_samples = [dataset[i] for i in batch_indices if dataset[i] is not None]

        if len(batch_samples) == 0:
            continue

        images, labels = zip(*batch_samples)
        images = jnp.stack(images)

        max_label_length = max(len(label) for label in labels)
        padded_labels = jnp.array([
            jnp.pad(label, (0, max_label_length - len(label)), constant_values=0)  # Ensure blank token at the end
            for label in labels
        ])

        yield images, padded_labels, jnp.array([len(label) for label in labels])


class CRNN(nn.Module):
    img_height: int
    num_classes: int
    lstm_hidden_size: int = 512
    num_lstm_layers: int = 2

    def setup(self):
        self.conv1 = nn.Conv(features=64, kernel_size=(3, 3), strides=1, padding='SAME')
        self.conv2 = nn.Conv(features=128, kernel_size=(3, 3), strides=1, padding='SAME')
        self.conv3 = nn.Conv(features=256, kernel_size=(3, 3), strides=1, padding='SAME')
        self.conv_proj = nn.Conv(features=256, kernel_size=(1, 1), strides=1, padding='SAME')
        self.fc = nn.Dense(features=self.num_classes)

    @nn.compact
    def __call__(self, x, train=True):
        def residual_block(x, conv, conv_proj, train):
            # main path
            y = nn.relu(conv(x))
            y = nn.BatchNorm(use_running_average=not train)(y)
            y = nn.Dropout(0.2, deterministic=not train)(y)
            # skip path (projection to match 256 channels)
            skip = conv_proj(x)
            return skip + y

        # --- Block 1 ---
        x = nn.relu(self.conv1(x))
        x = nn.BatchNorm(use_running_average=not train)(x)
        x = nn.Dropout(0.2, deterministic=not train)(x)
        x = nn.max_pool(x, window_shape=(2, 2), strides=(2, 2), padding='SAME')

        # --- Block 2 ---
        x = nn.relu(self.conv2(x))
        x = nn.BatchNorm(use_running_average=not train)(x)
        x = nn.Dropout(0.2, deterministic=not train)(x)
        x = nn.max_pool(x, window_shape=(2, 2), strides=(2, 2), padding='SAME')

        # --- Block 3: Single residual block ---
        x = residual_block(x, self.conv3, self.conv_proj, train)
        x = nn.max_pool(x, window_shape=(2, 2), strides=(2, 2), padding='SAME')

        # Flatten to (batch_size, width, height*channels)
        b, h, w, c = x.shape
        x_seq = x.reshape(b, w, h * c)

        # --- One Transformer Block (instead of two) ---
        def transformer_block(x):
            y = nn.LayerNorm()(x)
            y = nn.SelfAttention(num_heads=4, qkv_features=x.shape[-1])(y)  # fewer heads
            y = nn.Dropout(0.2, deterministic=not train)(y)
            return x + y

        x_seq = transformer_block(x_seq)

        # Final dense + log_softmax
        logits = self.fc(x_seq)
        return jax.nn.log_softmax(logits, axis=-1)



# ======= Compute Loss Function =======
def loss_fn_with_batch_stats(params, images, labels):
    logits, new_model_state = model.apply(
        {'params': params, 'batch_stats': batch_stats},
        images,
        train=True,
        mutable=['batch_stats'],
        rngs={'dropout': rng}  # Ensure dropout gets a PRNG key
    )
    logit_paddings = jnp.zeros((logits.shape[0], logits.shape[1]), dtype=jnp.int32)
    label_paddings = (labels == 0).astype(jnp.int32)
    loss = optax.ctc_loss(logits, logit_paddings, labels, label_paddings).mean()
    return loss, new_model_state['batch_stats']


# ======= Updated Train Step Function =======
@jax.jit
def train_step(params, batch_stats, opt_state, images, labels):
    def loss_fn_with_batch_stats(params, images, labels):
        logits, new_model_state = model.apply(
            {'params': params, 'batch_stats': batch_stats},
            images,
            train=True,
            mutable=['batch_stats'],
            rngs={'dropout': rng}  # Pass Dropout PRNG
        )
        logit_paddings = jnp.zeros((logits.shape[0], logits.shape[1]), dtype=jnp.int32)
        label_paddings = (labels == 0).astype(jnp.int32)
        loss = optax.ctc_loss(logits, logit_paddings, labels, label_paddings).mean()
        return loss, new_model_state['batch_stats']

    (loss, new_batch_stats), grads = jax.value_and_grad(loss_fn_with_batch_stats, has_aux=True)(params, images, labels)
    # Updated gradient clipping threshold (from ±1.0 to ±0.5)
    grads = jax.tree_util.tree_map(lambda g: jnp.clip(g, -0.5, 0.5) if g is not None else 0, grads)

    updates, opt_state = optimizer.update(grads, opt_state)
    params = optax.apply_updates(params, updates)

    return params, new_batch_stats, opt_state, loss


def compute_cer(preds, targets):
    total_chars, total_errors = 0, 0

    for pred, target in zip(preds, targets):
        pred_text = ''.join([index_to_char[i] for i in pred if i in index_to_char])
        target_text = ''.join([index_to_char[i] for i in target if i in index_to_char])

        total_chars += len(target_text)
        total_errors += editdistance.eval(pred_text, target_text)  # Using editdistance

    return total_errors / total_chars if total_chars > 0 else float("inf")

def greedy_decode(preds):
    decoded = []
    prev_char = None
    for i in preds:
        if i == 0:  # Skip blank characters (CTC blank)
            prev_char = None
            continue
        if i != prev_char:  # Avoid repeated characters (CTC rule)
            decoded.append(index_to_char.get(i, "?"))
        prev_char = i
    return "".join(decoded).strip()  # Remove leading/trailing spaces


def evaluate_model(dataset):
    total_loss, batch_count = 0, 0
    all_preds, all_targets = [], []

    for images, labels, label_lengths in jax_dataloader(dataset, batch_size=32, shuffle=False):
        loss, _ = loss_fn_with_batch_stats(params, images, labels)  # Correct loss function call
        total_loss += float(loss)  # Convert to float for accumulation
        batch_count += 1

        logits = model.apply({'params': params, 'batch_stats': batch_stats}, images, train=False, mutable=False)
        preds = jnp.argmax(logits, axis=-1).tolist()

        all_preds.extend(preds)
        all_targets.extend(labels.tolist())

    # Print a few decoded results
    for i in range(min(10, len(all_preds))):  # Avoid index errors if dataset is small
        pred_text = greedy_decode(all_preds[i])  # Use improved CTC decoding
        target_text = "".join([index_to_char.get(c, "?") for c in all_targets[i] if c > 0])  # Ignore padding

        print(f"Decoded Target: {target_text}")
        print(f"Decoded Prediction: {pred_text}")
        print("=" * 40)

    # Compute CER
    cer = compute_cer(all_preds, all_targets)
    avg_loss = total_loss / batch_count if batch_count > 0 else float("inf")

    return avg_loss, cer


# ======= Training Configuration =======
img_dir = "/content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words/"
label_file = "/content/handwriting_dataset_1/handwriting_dataset_1.zip/iam_words/words.txt"

dataset = IAMDataset(img_dir, label_file)
split_idx = int(0.8 * len(dataset))

train_dataset = IAMDataset(img_dir, label_file)
val_dataset = IAMDataset(img_dir, label_file)
train_dataset.valid_samples = dataset.valid_samples[:split_idx]
val_dataset.valid_samples = dataset.valid_samples[split_idx:]

num_classes = len(CHARS) + 1
model = CRNN(img_height=32, num_classes=num_classes, lstm_hidden_size=512)
rng = jax.random.PRNGKey(0)
dummy_input = jnp.ones((1, 32, 128, 1))
print("Dummy input shape:", dummy_input.shape)

variables = model.init({'params': rng, 'dropout': jax.random.PRNGKey(1)}, dummy_input, train=True)
params = variables['params']  # Extract model parameters
batch_stats = variables['batch_stats']  # Extract BatchNorm statistics

schedule = optax.exponential_decay(
    init_value=5e-4,  # Start lower
    transition_steps=500,
    decay_rate=0.95
)

optimizer = optax.adam(schedule)
opt_state = optimizer.init(params)  # Now params is defined


# ======= Train Model Function =======
def train_model(train_dataset, val_dataset, epochs=10):
    global params, batch_stats, opt_state
    for epoch in range(epochs):
        epoch_loss, batch_count = 0, 0

        for images, labels, label_lengths in jax_dataloader(train_dataset, batch_size=32):
            params, batch_stats, opt_state, loss = train_step(params, batch_stats, opt_state, images, labels)
            epoch_loss += float(loss)
            batch_count += 1

        avg_train_loss = epoch_loss / batch_count if batch_count > 0 else float("inf")
        val_loss, cer = evaluate_model(val_dataset)

        print(f"Epoch [{epoch + 1}/{epochs}], Loss: {avg_train_loss:.4f}, Val Loss: {val_loss:.4f}, CER: {cer:.4f}")


# ======= Train Model =======
train_model(train_dataset, val_dataset, epochs=40)
# Out:
# Dummy input shape: (1, 32, 128, 1)
# Decoded Target: "
# Decoded Prediction:
# ========================================
# Decoded Target: my
# Decoded Prediction:
# ========================================
# Decoded Target: background
# Decoded Prediction:
# ========================================
# Decoded Target: is
# Decoded Prediction:
# ========================================
# Decoded Target: a
# Decoded Prediction:
# ========================================
# Decoded Target: doctor
# Decoded Prediction:
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Epoch [1/40], Loss: 75.2767, Val Loss: 13.9033, CER: 1.0022
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction:
# ========================================
# Decoded Target: background
# Decoded Prediction: ,
# ========================================
# Decoded Target: is
# Decoded Prediction:
# ========================================
# Decoded Target: a
# Decoded Prediction:
# ========================================
# Decoded Target: doctor
# Decoded Prediction:
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Epoch [2/40], Loss: 71.7740, Val Loss: 13.3718, CER: 0.9975
# Decoded Target: "
# Decoded Prediction:
# ========================================
# Decoded Target: my
# Decoded Prediction:
# ========================================
# Decoded Target: background
# Decoded Prediction:
# ========================================
# Decoded Target: is
# Decoded Prediction:
# ========================================
# Decoded Target: a
# Decoded Prediction:
# ========================================
# Decoded Target: doctor
# Decoded Prediction:
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Epoch [3/40], Loss: 70.7224, Val Loss: 12.9524, CER: 1.0006
# Decoded Target: "
# Decoded Prediction:
# ========================================
# Decoded Target: my
# Decoded Prediction:
# ========================================
# Decoded Target: background
# Decoded Prediction: mreer
# ========================================
# Decoded Target: is
# Decoded Prediction:
# ========================================
# Decoded Target: a
# Decoded Prediction:
# ========================================
# Decoded Target: doctor
# Decoded Prediction:
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Epoch [4/40], Loss: 69.5457, Val Loss: 12.7787, CER: 0.9944
# Decoded Target: "
# Decoded Prediction:
# ========================================
# Decoded Target: my
# Decoded Prediction:
# ========================================
# Decoded Target: background
# Decoded Prediction: noeran
# ========================================
# Decoded Target: is
# Decoded Prediction:
# ========================================
# Decoded Target: a
# Decoded Prediction: ,
# ========================================
# Decoded Target: doctor
# Decoded Prediction:
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Epoch [5/40], Loss: 68.8276, Val Loss: 11.9928, CER: 0.9689
# Decoded Target: "
# Decoded Prediction:
# ========================================
# Decoded Target: my
# Decoded Prediction:
# ========================================
# Decoded Target: background
# Decoded Prediction: mememdnmd
# ========================================
# Decoded Target: is
# Decoded Prediction:
# ========================================
# Decoded Target: a
# Decoded Prediction:
# ========================================
# Decoded Target: doctor
# Decoded Prediction:
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Epoch [6/40], Loss: 68.0476, Val Loss: 12.2775, CER: 0.9647
# Decoded Target: "
# Decoded Prediction:
# ========================================
# Decoded Target: my
# Decoded Prediction:
# ========================================
# Decoded Target: background
# Decoded Prediction: momranan
# ========================================
# Decoded Target: is
# Decoded Prediction:
# ========================================
# Decoded Target: a
# Decoded Prediction:
# ========================================
# Decoded Target: doctor
# Decoded Prediction: tat
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Epoch [7/40], Loss: 67.2743, Val Loss: 12.1543, CER: 0.9435
# Decoded Target: "
# Decoded Prediction:
# ========================================
# Decoded Target: my
# Decoded Prediction:
# ========================================
# Decoded Target: background
# Decoded Prediction: mnmnn
# ========================================
# Decoded Target: is
# Decoded Prediction:
# ========================================
# Decoded Target: a
# Decoded Prediction:
# ========================================
# Decoded Target: doctor
# Decoded Prediction:
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Epoch [8/40], Loss: 66.5867, Val Loss: 12.1490, CER: 0.9354
# Decoded Target: "
# Decoded Prediction:
# ========================================
# Decoded Target: my
# Decoded Prediction:
# ========================================
# Decoded Target: background
# Decoded Prediction: nrnmangn
# ========================================
# Decoded Target: is
# Decoded Prediction:
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: mwtr
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction: n
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Epoch [9/40], Loss: 65.9974, Val Loss: 12.3372, CER: 0.8942
# Decoded Target: "
# Decoded Prediction:
# ========================================
# Decoded Target: my
# Decoded Prediction:
# ========================================
# Decoded Target: background
# Decoded Prediction: mremrnanan
# ========================================
# Decoded Target: is
# Decoded Prediction: s
# ========================================
# Decoded Target: a
# Decoded Prediction:
# ========================================
# Decoded Target: doctor
# Decoded Prediction: t
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Epoch [10/40], Loss: 65.7455, Val Loss: 12.3996, CER: 0.9021
# Decoded Target: "
# Decoded Prediction:
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: mrnmrmnandnd
# ========================================
# Decoded Target: is
# Decoded Prediction: s
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: taor
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [11/40], Loss: 64.9405, Val Loss: 12.2860, CER: 0.8892
# Decoded Target: "
# Decoded Prediction:
# ========================================
# Decoded Target: my
# Decoded Prediction:
# ========================================
# Decoded Target: background
# Decoded Prediction: mrmmumadn
# ========================================
# Decoded Target: is
# Decoded Prediction: n
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: toc
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [12/40], Loss: 64.4838, Val Loss: 12.9533, CER: 0.8481
# Decoded Target: "
# Decoded Prediction:
# ========================================
# Decoded Target: my
# Decoded Prediction: y
# ========================================
# Decoded Target: background
# Decoded Prediction: nrnesormed
# ========================================
# Decoded Target: is
# Decoded Prediction: s
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: tohs
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Epoch [13/40], Loss: 64.1949, Val Loss: 12.7506, CER: 0.8461
# Decoded Target: "
# Decoded Prediction:
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: nnsnmen
# ========================================
# Decoded Target: is
# Decoded Prediction:
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: tor
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Epoch [14/40], Loss: 63.3737, Val Loss: 13.3867, CER: 0.8579
# Decoded Target: "
# Decoded Prediction:
# ========================================
# Decoded Target: my
# Decoded Prediction: y
# ========================================
# Decoded Target: background
# Decoded Prediction: oannunmuan
# ========================================
# Decoded Target: is
# Decoded Prediction: n
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: to
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [15/40], Loss: 62.9873, Val Loss: 13.4323, CER: 0.8411
# Decoded Target: "
# Decoded Prediction:
# ========================================
# Decoded Target: my
# Decoded Prediction: my
# ========================================
# Decoded Target: background
# Decoded Prediction: mnnrmednd
# ========================================
# Decoded Target: is
# Decoded Prediction: n
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: tdor
# ========================================
# Decoded Target: of
# Decoded Prediction: o
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction: n
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [16/40], Loss: 62.3156, Val Loss: 13.9727, CER: 0.8274
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction:
# ========================================
# Decoded Target: background
# Decoded Prediction: nnrndadn
# ========================================
# Decoded Target: is
# Decoded Prediction: i
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: to
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Epoch [17/40], Loss: 62.1597, Val Loss: 14.1545, CER: 0.8055
# Decoded Target: "
# Decoded Prediction:
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: monnmunmn
# ========================================
# Decoded Target: is
# Decoded Prediction: s
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: mo-
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [18/40], Loss: 61.9900, Val Loss: 14.3883, CER: 0.8520
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: mamnmrnmen
# ========================================
# Decoded Target: is
# Decoded Prediction: n
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: mi
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction: n
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [19/40], Loss: 61.5080, Val Loss: 14.8032, CER: 0.8551
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: y
# ========================================
# Decoded Target: background
# Decoded Prediction: naonmdan
# ========================================
# Decoded Target: is
# Decoded Prediction: s
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: ah
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [20/40], Loss: 61.0160, Val Loss: 14.8587, CER: 0.8195
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: nnrann
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: aoosr
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: s
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [21/40], Loss: 60.6466, Val Loss: 15.9258, CER: 0.8125
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: naonmrnanadn
# ========================================
# Decoded Target: is
# Decoded Prediction: i
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: ohr
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [22/40], Loss: 60.4721, Val Loss: 15.4262, CER: 0.7949
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: manoaneadn
# ========================================
# Decoded Target: is
# Decoded Prediction: n
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: a
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction: a
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [23/40], Loss: 60.1844, Val Loss: 16.1387, CER: 0.7865
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: maonrnmndn
# ========================================
# Decoded Target: is
# Decoded Prediction: i
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: muard
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [24/40], Loss: 60.1623, Val Loss: 16.3684, CER: 0.7910
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: nannunmn
# ========================================
# Decoded Target: is
# Decoded Prediction: ns
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: auo
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [25/40], Loss: 60.2045, Val Loss: 16.4864, CER: 0.8167
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: oneumen
# ========================================
# Decoded Target: is
# Decoded Prediction: i
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: lo
# ========================================
# Decoded Target: of
# Decoded Prediction: f
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Epoch [26/40], Loss: 59.7659, Val Loss: 16.6230, CER: 0.7843
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction:
# ========================================
# Decoded Target: background
# Decoded Prediction: ononeunmen
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: d
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction: a
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [27/40], Loss: 59.6368, Val Loss: 16.7900, CER: 0.8030
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: oneradnddnd
# ========================================
# Decoded Target: is
# Decoded Prediction: ns
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: do
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Epoch [28/40], Loss: 59.3855, Val Loss: 17.5129, CER: 0.7985
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: onrnauan
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: mo
# ========================================
# Decoded Target: of
# Decoded Prediction: f
# ========================================
# Decoded Target: 68
# Decoded Prediction: s
# ========================================
# Decoded Target: ,
# Decoded Prediction: a
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [29/40], Loss: 59.4096, Val Loss: 17.7567, CER: 0.8050
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: onrnadmdn
# ========================================
# Decoded Target: is
# Decoded Prediction: i
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: mo
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: as
# ========================================
# Decoded Target: ,
# Decoded Prediction: a
# ========================================
# Decoded Target: who
# Decoded Prediction: n.
# ========================================
# Epoch [30/40], Loss: 59.2298, Val Loss: 17.8058, CER: 0.7957
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: mm
# ========================================
# Decoded Target: background
# Decoded Prediction: onramadn
# ========================================
# Decoded Target: is
# Decoded Prediction: i
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: mo
# ========================================
# Decoded Target: of
# Decoded Prediction: f
# ========================================
# Decoded Target: 68
# Decoded Prediction: s
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: .
# ========================================
# Epoch [31/40], Loss: 59.2543, Val Loss: 18.5586, CER: 0.8055
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: noneradadn
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: ado
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: ts
# ========================================
# Decoded Target: ,
# Decoded Prediction: n
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [32/40], Loss: 59.2549, Val Loss: 17.8187, CER: 0.7871
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: nonremdmdn
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: ano
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction: o
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [33/40], Loss: 58.9409, Val Loss: 18.4410, CER: 0.7826
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: nonrnadan
# ========================================
# Decoded Target: is
# Decoded Prediction: ns
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: ono
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction: "
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [34/40], Loss: 59.1907, Val Loss: 18.8787, CER: 0.7840
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: oonronden
# ========================================
# Decoded Target: is
# Decoded Prediction: i
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: ao
# ========================================
# Decoded Target: of
# Decoded Prediction: t
# ========================================
# Decoded Target: 68
# Decoded Prediction: t
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Epoch [35/40], Loss: 58.8075, Val Loss: 18.8714, CER: 0.7639
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: nonrnaden
# ========================================
# Decoded Target: is
# Decoded Prediction: n
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: adm
# ========================================
# Decoded Target: of
# Decoded Prediction: f
# ========================================
# Decoded Target: 68
# Decoded Prediction: a
# ========================================
# Decoded Target: ,
# Decoded Prediction: a
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [36/40], Loss: 58.6763, Val Loss: 19.5225, CER: 0.7790
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: my
# ========================================
# Decoded Target: background
# Decoded Prediction: nnunamn
# ========================================
# Decoded Target: is
# Decoded Prediction: i
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: do
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: as
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Epoch [37/40], Loss: 58.7657, Val Loss: 19.7364, CER: 0.7658
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: oennunamn
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: do
# ========================================
# Decoded Target: of
# Decoded Prediction: i
# ========================================
# Decoded Target: 68
# Decoded Prediction: s
# ========================================
# Decoded Target: ,
# Decoded Prediction:
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [38/40], Loss: 58.6893, Val Loss: 20.5542, CER: 0.7767
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: my
# ========================================
# Decoded Target: background
# Decoded Prediction: nonrndn
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: dnor
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction: s
# ========================================
# Decoded Target: ,
# Decoded Prediction: o
# ========================================
# Decoded Target: who
# Decoded Prediction: n
# ========================================
# Epoch [39/40], Loss: 58.5752, Val Loss: 20.2002, CER: 0.7717
# Decoded Target: "
# Decoded Prediction: "
# ========================================
# Decoded Target: my
# Decoded Prediction: m
# ========================================
# Decoded Target: background
# Decoded Prediction: nnrnadn
# ========================================
# Decoded Target: is
# Decoded Prediction: is
# ========================================
# Decoded Target: a
# Decoded Prediction: a
# ========================================
# Decoded Target: doctor
# Decoded Prediction: aor
# ========================================
# Decoded Target: of
# Decoded Prediction:
# ========================================
# Decoded Target: 68
# Decoded Prediction:
# ========================================
# Decoded Target: ,
# Decoded Prediction: a
# ========================================
# Decoded Target: who
# Decoded Prediction:
# ========================================
# Epoch [40/40], Loss: 58.5430, Val Loss: 20.2327, CER: 0.7837
